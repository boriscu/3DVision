# %%
# !git clone --recursive https://github.com/naver/mast3r.git
# %cd mast3r
# Out:
# Cloning into 'mast3r'...
# remote: Enumerating objects: 248, done.
# remote: Counting objects: 100% (179/179), done.
# remote: Compressing objects: 100% (75/75), done.
# remote: Total 248 (delta 125), reused 109 (delta 104), pack-reused 69 (from 2)
# Receiving objects: 100% (248/248), 3.59 MiB | 36.01 MiB/s, done.
# Resolving deltas: 100% (133/133), done.
# Submodule 'dust3r' (https://github.com/naver/dust3r) registered for path 'dust3r'
# Cloning into '/content/mast3r/dust3r'...
# remote: Enumerating objects: 559, done.
# remote: Counting objects: 100% (411/411), done.
# remote: Compressing objects: 100% (213/213), done.
# remote: Total 559 (delta 298), reused 199 (delta 198), pack-reused 148 (from 2)
# Receiving objects: 100% (559/559), 735.09 KiB | 13.87 MiB/s, done.
# Resolving deltas: 100% (324/324), done.
# Submodule path 'dust3r': checked out 'c9e9336a6ba7c1f1873f9295852cea6dffaf770d'
# Submodule 'croco' (https://github.com/naver/croco) registered for path 'dust3r/croco'
# ...

# %%
# !pip uninstall -y torch torchvision torchaudio
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# Out:
# WARNING: Skipping torch as it is not installed.
# WARNING: Skipping torchvision as it is not installed.
# WARNING: Skipping torchaudio as it is not installed.
# Looking in indexes: https://download.pytorch.org/whl/cu118
# ...
#   Using cached https://download.pytorch.org/whl/cu118/torch-2.7.0%2Bcu118-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (28 kB)
# ...
#   Using cached https://download.pytorch.org/whl/sympy-1.13.3-py3-none-any.whl.metadata (12 kB)
# ...
#   Using cached https://download.pytorch.org/whl/triton-3.3.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.5 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 955.6/955.6 MB 9.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.5/156.5 MB 18.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 43.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 73.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 80.0 MB/s eta 0:00:00
# ...

# %%
# !pip install -r requirements.txt
# !pip install -r dust3r/requirements.txt
# !pip install -r dust3r/requirements_optional.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 27.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.2/54.2 MB 57.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 711.2/711.2 kB 19.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.5/11.5 MB 127.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17/17 [gradio]
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 50.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 87.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 63.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.5/12.5 MB 132.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 61.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 51.5 MB/s eta 0:00:00
# ...

# %%
# !pip install faiss-gpu-cu11
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.0/48.0 MB 77.5 MB/s eta 0:00:00
# ...

# %%
# !pip install cython
# !git clone https://github.com/jenicek/asmk.git
# %cd asmk/cython
# !cythonize *.pyx
# %cd ../
# !pip install .
# %cd /content/mast3r
# Out:
# ...
# fatal: destination path 'asmk' already exists and is not an empty directory.
# /content/mast3r/asmk/cython
# /content/mast3r/asmk
# Processing /content/mast3r/asmk
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached pyaml-25.5.0-py3-none-any.whl.metadata (12 kB)
# ...
# Using cached pyaml-25.5.0-py3-none-any.whl (26 kB)
# ...
#   DEPRECATION: Building 'asmk' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'asmk'. Discussion can be found at https://github.com/pypa/pip/issues/6334
# ...
#   Created wheel for asmk: filename=asmk-0.1-cp311-cp311-linux_x86_64.whl size=420185 sha256=7f1cffcac10b87d59261ec9806b57a7041ec5e85fff2dbc8815c624b4d291800
# ...

# %%
# !pip install pyngrok

# %%
from pyngrok import ngrok
ngrok.set_auth_token("2XXn2obYzYoUng6aX6XYwQMYq9G_4c71Rjz1Vvo74jEXRHwxa")
url = ngrok.connect(7860)
print("Ngrok Tunnel URL:", url)
# Out:
# Ngrok Tunnel URL: NgrokTunnel: "https://652a-35-230-116-95.ngrok-free.app" -> "http://localhost:7860"

# %%
# !python3 demo.py --model_name MASt3R_ViTLarge_BaseDecoder_512_catmlpdpt_metric
# Out:
# /content/mast3r/dust3r/dust3r/cloud_opt/base_opt.py:275: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @torch.cuda.amp.autocast(enabled=False)
# Warning, cannot find cuda-compiled version of RoPE2D, using a slow pytorch version instead
# config.json: 100% 546/546 [00:00<00:00, 2.87MB/s]
# model.safetensors: 100% 2.75G/2.75G [00:36<00:00, 76.3MB/s]
# [2025-05-29 17:57:13] Outputing stuff in /tmp/tmplanes_si_mast3r_gradio_demo/a80583ad5217858177c4ebdcac94a5fd
# [2025-05-29 17:57:13] * Running on local URL:  http://127.0.0.1:7860
# [2025-05-29 17:57:14] * To create a public link, set `share=True` in `launch()`.
# [2025-05-29 17:58:31] >> Loading a list of 7 images
# [2025-05-29 17:58:31]  - adding /tmp/gradio/084f83816932adcc75cb248e1c15080571050628741f96fc9082fa9aa8675be8/color_cam0_14442C10114C11D100.png with resolution 1920x1080 --> 512x288
# ...
